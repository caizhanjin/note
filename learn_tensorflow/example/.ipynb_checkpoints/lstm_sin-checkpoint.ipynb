# %%
# -*- coding: utf-8 -*-
import numpy as np
import tensorflow as tf

import matplotlib as mpl
mpl.use('TkAgg')
from matplotlib import pyplot as plt

hidden_size = 30
num_layers = 2

time_steps = 10
training_steps = 100
batch_size = 32

training_examples = 10000
testing_examples = 1000
# 采样间隔
sample_gap = 0.01


def generate_data(seq):
    """用sin函数前面的time_steps个点的值，预测第i + time_steps点的函数值"""
    X = []
    y = []
    for i in range(len(seq) - time_steps):
        X.append([seq[i: i + time_steps]])
        y.append([seq[i + time_steps]])
    # x->[None, 1, time_steps] y->[None, 1]
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)


def lstm_model(X, y, is_training):
    """lstm_model 模型"""
    cell = tf.nn.rnn_cell.MultiRNNCell([
        tf.nn.rnn_cell.BasicLSTMCell(hidden_size)
        for _ in range(num_layers)
    ])
    
    # X->[batch_size, 1, time_steps] ,  outputs->[batch_size, 1, hidden_size]
    outputs, _ = tf.nn.dynamic_rnn(cell, X, dtype=tf.float32)
    
    # [batch_size, hidden_size]
    output = outputs[:, -1, :]
    
    # [batch_size, 1]
    predictions = tf.contrib.layers.fully_connected(
        output, 1, activation_fn=None
    )

    if not is_training:
        return predictions, None, None

    loss = tf.losses.mean_squared_error(labels=y, predictions=predictions)

    # 优化
    train_op = tf.contrib.layers.optimize_loss(
        loss,
        tf.train.get_global_step(),
        optimizer="Adagrad",
        learning_rate=0.1
    )

    return predictions, loss, train_op


def train(sess, train_X, train_y):
    ds = tf.data.Dataset.from_tensor_slices((train_X, train_y))
    ds = ds.repeat().shuffle(1000).batch(batch_size)
    X, y = ds.make_one_shot_iterator().get_next()

    # 创建模型
    with tf.variable_scope("model"):
        predictions, loss, train_op = lstm_model(X, y, True)

    sess.run(tf.global_variables_initializer())
    for i in range(training_steps):
        _, l = sess.run([train_op, loss])
        if i % 100 == 0:
            print("train step: " + str(i) + ", loss: " + str(l))


def run_eval(sess, test_X, test_y):
    ds = tf.data.Dataset.from_tensor_slices((test_X, test_y))
    ds = ds.batch(1)
    X, y = ds.make_one_shot_iterator().get_next()

    with tf.variable_scope("model", reuse=True):
        prediction, _, _ = lstm_model(X, [0.0], False)
    predictions = []
    labels = []
    for i in range(testing_examples):
        p, l = sess.run([prediction, y])
        predictions.append(p)
        labels.append(l)

    predictions = np.array(predictions).squeeze()
    print(predictions)
    labels = np.array(labels).squeeze()
    rmse = np.sqrt(((predictions - labels) ** 2).mean(axis=0))
    print("Mean Square Error is : %f" % rmse)

    plt.figure()
    plt.plot(predictions, label='predictions')
    plt.plot(labels, label='labels')
    plt.legend()
    plt.show()

# 生成数据 
test_start = (training_examples + time_steps) * sample_gap
test_end = test_start + (testing_examples + time_steps) * sample_gap
train_X, train_y = generate_data(np.sin(np.linspace(
    0, test_start, training_examples+time_steps, dtype=np.float32)))
test_X, test_y = generate_data(np.sin(np.linspace(
    test_start, test_end, testing_examples + time_steps, dtype=np.float32)))

with tf.Session() as sess:
    train(sess, train_X, train_y)
    run_eval(sess, test_X, test_y)
# Out:
# WARNING:tensorflow:From <ipython-input-1-e59da4d4485b>:37: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# train step: 0, loss: 0.4470234
# [[-0.2279485]]
# [[-0.2418326]]
# [array([[-0.45125395]], dtype=float32), array([[-0.4412136]], dtype=float32), array([[-0.43103516]], dtype=float32), array([[-0.42071956]], dtype=float32), array([[-0.41026765]], dtype=float32), array([[-0.39968055]], dtype=float32), array([[-0.38895923]], dtype=float32), array([[-0.3781044]], dtype=float32), array([[-0.3671183]], dtype=float32), array([[-0.3560025]], dtype=float32), array([[-0.34475905]], dtype=float32), array([[-0.33338964]], dtype=float32), array([[-0.32189697]], dtype=float32), array([[-0.31028324]], dtype=float32), array([[-0.29855043]], dtype=float32), array([[-0.28670174]], dtype=float32), array([[-0.2747401]], dtype=float32), array([[-0.26266962]], dtype=float32), array([[-0.2504924]], dtype=float32), array([[-0.23821194]], dtype=float32), array([[-0.22583203]], dtype=float32), array([[-0.21335627]], dtype=float32), array([[-0.2007888]], dtype=float32), array([[-0.18813363]], dtype=float32), array([[-0.17539515]], dtype=float32), array([[-0.16257776]], dtype=float32), array([[-0.14968623]], dtype=float32), array([[-0.13672519]], dtype=float32), array([[-0.12369962]], dtype=float32), array([[-0.11061458]], dtype=float32), array([[-0.09747525]], dtype=float32), array([[-0.08428688]], dtype=float32), array([[-0.07105493]], dtype=float32), array([[-0.05778485]], dtype=float32), array([[-0.04448225]], dtype=float32), array([[-0.03115279]], dtype=float32), array([[-0.01780222]], dtype=float32), array([[-0.00443631]], dtype=float32), array([[0.00893911]], dtype=float32), array([[0.02231818]], dtype=float32), array([[0.03569503]], dtype=float32), array([[0.04906377]], dtype=float32), array([[0.06241854]], dtype=float32), array([[0.07575347]], dtype=float32), array([[0.08906275]], dtype=float32), array([[0.10234059]], dtype=float32), array([[0.11558128]], dtype=float32), array([[0.12877914]], dtype=float32), array([[0.14192866]], dtype=float32), array([[0.15502429]], dtype=float32), array([[0.16806068]], dtype=float32), array([[0.18103254]], dtype=float32), array([[0.19393471]], dtype=float32), array([[0.20676222]], dtype=float32), array([[0.21951011]], dtype=float32), array([[0.23217379]], dtype=float32), array([[0.24474852]], dtype=float32), array([[0.25722995]], dtype=float32), array([[0.26961383]], dtype=float32), array([[0.2818961]], dtype=float32), array([[0.29407382]], dtype=float32), array([[0.30614203]], dtype=float32), array([[0.3180976]], dtype=float32), array([[0.3299371]], dtype=float32), array([[0.34165746]], dtype=float32), array([[0.35325503]], dtype=float32), array([[0.36472756]], dtype=float32), array([[0.37607282]], dtype=float32), array([[0.3872879]], dtype=float32), array([[0.39837044]], dtype=float32), array([[0.40931803]], dtype=float32), array([[0.4201293]], dtype=float32), array([[0.43080282]], dtype=float32), array([[0.441337]], dtype=float32), array([[0.4517306]], dtype=float32), array([[0.46198243]], dtype=float32), array([[0.47209156]], dtype=float32), array([[0.48205698]], dtype=float32), array([[0.49187827]], dtype=float32), array([[0.5015548]], dtype=float32), array([[0.5110863]], dtype=float32), array([[0.52047247]], dtype=float32), array([[0.5297131]], dtype=float32), array([[0.5388085]], dtype=float32), array([[0.54775876]], dtype=float32), array([[0.5565641]], dtype=float32), array([[0.5652249]], dtype=float32), array([[0.57374173]], dtype=float32), array([[0.5821152]], dtype=float32), array([[0.59034604]], dtype=float32), array([[0.59843487]], dtype=float32), array([[0.6063829]], dtype=float32), array([[0.6141908]], dtype=float32), array([[0.6218598]], dtype=float32), array([[0.6293908]], dtype=float32), array([[0.63678527]], dtype=float32), array([[0.6440441]], dtype=float32), array([[0.6511687]], dtype=float32), array([[0.65816057]], dtype=float32), array([[0.66502094]], dtype=float32), array([[0.6717512]], dtype=float32), array([[0.6783527]], dtype=float32), array([[0.6848274]], dtype=float32), array([[0.6911761]], dtype=float32), array([[0.697401]], dtype=float32), array ...
# Mean Square Error is : 0.077741

# %%
import numpy as np
x = np.array([[
    [23,23,23,23]
],[
    [23,23,23,23]
]])
y = x[:, -1, :]
print(x.shape)
print(x)
print(y.shape)
print(y)
